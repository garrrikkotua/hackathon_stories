# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv('transformed_customer_test.csv')

# %%
stories = pd.read_csv('stories_reaction_test.csv')

# %%
customers.head()
# Out:
#    customer_id   age  full_years  gender  product_0_CLS  product_0_NaN  \
# 0           15  40.0         7.0       1              0              1
# 1           73  45.0         7.0       1              1              0
# 2           91  40.0         6.0       1              0              1
# 3          129  45.0         6.0       1              0              1
# 4          144  50.0         6.0       1              0              1
#
#    product_0_UTL  product_1_CLS  product_1_NaN  product_1_OPN  ...  \
# 0              0              1              0              0  ...
# 1              0              1              0              0  ...
# 2              0              1              0              0  ...
# 3              0              0              0              0  ...
# 4              0              0              0              0  ...
#
#     4111_mean   4121_mean  5331_mean    5411_mean  5499_mean    5541_mean  \
# ...

# %%
stories.head()
# Out:
#    customer_id  story_id           event_dttm  answer_id
# 0       466906      1152  2018-08-01 00:00:46          0
# 1       466906      1355  2018-08-01 00:00:46          1
# 2       146395       537  2018-08-01 00:02:08          2
# 3       897303       915  2018-08-01 00:02:30          3
# 4        50094      1415  2018-08-01 00:03:13          4

# %%
customers.set_index('customer_id', inplace=True)

# %%
customers
# Out:
#                    age  full_years  gender  product_0_CLS  product_0_NaN  \
# customer_id
# 15           40.000000    7.000000       1              0              1
# 73           45.000000    7.000000       1              1              0
# 91           40.000000    6.000000       1              0              1
# 129          45.000000    6.000000       1              0              1
# 144          50.000000    6.000000       1              0              1
# 150          45.000000    7.000000       1              0              1
# 164          50.000000    4.000000       0              0              1
# 178          35.000000    7.000000       1              0              1
# 183          50.000000    7.000000       0              0              1
# 192          40.000000    5.000000       1              0              1
# 353          45.000000    5.000000       1              0              1
# 362          30.000000    7.000000       1              0              1
# ...

# %%
data = stories.join(customers, on='customer_id')

# %%
data.head()
# Out:
#    customer_id  story_id           event_dttm  answer_id   age  full_years  \
# 0       466906      1152  2018-08-01 00:00:46          0  25.0         2.0
# 1       466906      1355  2018-08-01 00:00:46          1  25.0         2.0
# 2       146395       537  2018-08-01 00:02:08          2  25.0         1.0
# 3       897303       915  2018-08-01 00:02:30          3  30.0         1.0
# 4        50094      1415  2018-08-01 00:03:13          4  30.0         7.0
#
#    gender  product_0_CLS  product_0_NaN  product_0_UTL  ...   4111_mean  \
# 0       0              0              1              0  ...  500.000000
# 1       0              0              1              0  ...  500.000000
# 2       1              0              1              0  ...    0.000000
# 3       0              0              1              0  ...    0.000000
# 4       1              0              0              1  ...  333.333333
#
#    4121_mean  5331_mean  5411_mean   5499_mean    5541_mean  5812_mean  \
# ...

# %%
len(stories)
# Out:
# 172049

# %%
len(data)
# Out:
# 172049

# %%
img = pd.read_csv('encoded_image_vectors.csv')
img.set_index('Unnamed: 0', inplace=True)
img.columns = ['img_{}'.format(i) for i in range(200)]
img.head()
# Out:
#                 img_0     img_1     img_2     img_3     img_4     img_5  \
# Unnamed: 0
# 1000         6.451160 -3.551597  2.812647 -7.786051 -1.854129 -0.788550
# 1001        10.679192 -4.654103  0.394651 -6.067107 -0.782128 -2.698834
# 1002         7.322650 -5.719898 -4.426306  4.446971 -0.268286  2.689194
# 1003       -15.293322  1.234061 -6.914356 -0.399876 -3.622600 -0.897216
# 1004       -16.290875  2.544510 -9.038565  0.331856 -5.306731 -1.597454
#
#                img_6     img_7     img_8     img_9  ...   img_190   img_191  \
# Unnamed: 0                                          ...
# 1000       -3.640428 -1.006964  0.593710  0.390803  ... -0.036982 -0.037476
# 1001       -2.202642 -0.949290  1.444721  1.441624  ... -0.083016 -0.564499
# 1002        1.617716 -0.322713 -3.013821  0.333235  ...  0.093319  0.079550
# 1003       -2.362806 -0.876070  2.302003  1.742938  ...  0.228319  0.366406
# 1004       -1.247256 -0.652486  2.189082  1.610730  ...  0.093335 -0.050184
#
# ...

# %%
img.index.name = None

# %%
words = pd.read_csv('stories_textvecs.csv')
words.set_index('story_id', inplace=True)
words.head()
# Out:
#             coord0    coord1    coord2    coord3    coord4    coord5  \
# story_id
# 127       0.023946  0.027339 -0.036125  0.014271 -0.022873  0.058570
# 254       0.040182 -0.010477 -0.039391  0.003636 -0.037800  0.060992
# 865       0.014239 -0.008430 -0.009091  0.009896 -0.014337  0.014273
# 1491      0.004958  0.007709  0.015407  0.030614 -0.018569  0.014779
# 598      -0.021650  0.010285  0.020996  0.011718 -0.016412  0.007425
#
#             coord6    coord7    coord8    coord9  ...  coord290  coord291  \
# story_id                                          ...
# 127       0.009791  0.026809 -0.013737 -0.043432  ... -0.021669  0.002791
# 254       0.014580 -0.037330 -0.011485 -0.056440  ... -0.017745 -0.004105
# 865      -0.005956 -0.012593 -0.006753 -0.021712  ... -0.006727  0.025462
# 1491     -0.001456  0.006372 -0.020365 -0.002415  ...  0.004823  0.031571
# 598       0.005012  0.010852  0.018671 -0.006876  ...  0.004557 -0.000098
#
# ...

# %%
words.index.name = None

# %%
descr = img.join(words)

# %%
descr
# Out:
#              img_0         img_1         img_2         img_3      img_4  \
# 1000  6.451160e+00 -3.551597e+00  2.812647e+00 -7.786051e+00  -1.854129
# 1001  1.067919e+01 -4.654103e+00  3.946509e-01 -6.067107e+00  -0.782128
# 1002  7.322650e+00 -5.719898e+00 -4.426306e+00  4.446971e+00  -0.268286
# 1003 -1.529332e+01  1.234061e+00 -6.914356e+00 -3.998759e-01  -3.622600
# 1004 -1.629088e+01  2.544510e+00 -9.038565e+00  3.318558e-01  -5.306731
# 1005  2.918628e+01  1.318676e+01 -1.320342e+01  1.129890e+01  -6.695161
# 1006  8.424971e+00 -1.560098e-01 -6.099788e-01 -4.935732e+00  -0.506561
# 1007  8.273198e+00 -6.440009e+00 -4.511240e+00  8.114493e-01   0.528774
# 1008  1.756023e+01  1.271872e+01 -5.195028e+00  6.708866e+00   0.143731
# 1009  9.967084e+00 -2.131223e+00  1.886695e+00 -6.584910e+00  -3.310026
# 1010  4.947181e+00 -4.948730e+00  1.070956e+00 -3.176410e+00  -1.024801
# 1011 -1.730391e+01  8.224909e-01 -8.438857e+00 -1.352283e+00  -3.734814
# ...

# %%
len(descr)
# Out:
# 959

# %%
data = data.join(descr, on='story_id')

# %%
data.head()
# Out:
#    customer_id  story_id           event_dttm  answer_id   age  full_years  \
# 0       466906      1152  2018-08-01 00:00:46          0  25.0         2.0
# 1       466906      1355  2018-08-01 00:00:46          1  25.0         2.0
# 2       146395       537  2018-08-01 00:02:08          2  25.0         1.0
# 3       897303       915  2018-08-01 00:02:30          3  30.0         1.0
# 4        50094      1415  2018-08-01 00:03:13          4  30.0         7.0
#
#    gender  product_0_CLS  product_0_NaN  product_0_UTL  ...  coord290  \
# 0       0              0              1              0  ...  0.009240
# 1       0              0              1              0  ...  0.010601
# 2       1              0              1              0  ... -0.014660
# 3       0              0              1              0  ... -0.000867
# 4       1              0              0              1  ...  0.008177
#
#    coord291  coord292  coord293  coord294  coord295  coord296  coord297  \
# ...

# %%
data.drop(columns=['customer_id', 'story_id', 'event_dttm'], inplace=True)

# %%
data.head()
# Out:
#    answer_id   age  full_years  gender  product_0_CLS  product_0_NaN  \
# 0          0  25.0         2.0       0              0              1
# 1          1  25.0         2.0       0              0              1
# 2          2  25.0         1.0       1              0              1
# 3          3  30.0         1.0       0              0              1
# 4          4  30.0         7.0       1              0              0
#
#    product_0_UTL  product_1_CLS  product_1_NaN  product_1_OPN  ...  coord290  \
# 0              0              0              1              0  ...  0.009240
# 1              0              0              1              0  ...  0.010601
# 2              0              0              0              0  ... -0.014660
# 3              0              0              0              0  ... -0.000867
# 4              1              0              1              0  ...  0.008177
#
#    coord291  coord292  coord293  coord294  coord295  coord296  coord297  \
# ...

# %%
len(data)
# Out:
# 172049

# %%
data.to_csv(path_or_buf='test_dataset.csv')
